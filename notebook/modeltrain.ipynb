# %%
# Out:
# prajwal

# %%
import numpy as np 
import pandas as pd 
import  matplotlib.pyplot as plt 
import seaborn as sns

# %%
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostRegressor 
from xgboost import XGBRegressor
import warnings

# %%
df=pd.read_csv(r'C:\Users\prajw\OneDrive\Desktop\macine learning project 01\notebook\data\StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
x=df.drop(columns=['math score'],axis=1)

# %%
y=df["math score"]

# %%
x.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  reading score  writing score
# 0                    none             72             74
# 1               completed             90             88

# %%
print("categorical feature in unique is the :",end=" ")
print(x["gender"].unique())
print("categorical feature in a uniques raceend ethnicity is: ",end=" ")
print(x["race/ethnicity"].unique())
print("categorical feature in a parental level of education :",end=" ")
print(x["parental level of education"].unique())
print("categorical feature in a lunch : ",end=" ")
print(x["lunch"].unique())
print("categorical feature in a test preparation course : ",end=" ")
print(x["test preparation course"].unique())
# Out:
# categorical feature in unique is the : ['female' 'male']
# categorical feature in a uniques raceend ethnicity is:  ['group B' 'group C' 'group A' 'group D' 'group E']
# categorical feature in a parental level of education : ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# categorical feature in a lunch :  ['standard' 'free/reduced']
# categorical feature in a test preparation course :  ['none' 'completed']

# %%
y.head(2)
# Out:
# 0    72
# 1    69
# Name: math score, dtype: int64

# %%
num_feature=x.select_dtypes(exclude="object").columns
cat_feature=x.select_dtypes(include="object").columns
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
numeric_transformer=StandardScaler()
onehotencoding_transformer=OneHotEncoder()

preprocessor=ColumnTransformer(
    [
        ("OneHotEncoder",onehotencoding_transformer,cat_feature),
        ("standardscaler",numeric_transformer,num_feature)


    ]
)

# %%
x=preprocessor.fit_transform(x)

# %%
x.shape
# Out:
# (1000, 19)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape
# Out:
# ((800, 19), (200, 19))

# %%
def evaluate_model(true,predicted):
    mae=mean_absolute_error(true,predicted)
    mse=mean_squared_error(true,predicted)
    rmse=np.sqrt(mean_squared_error(true,predicted))
    r2_score=r2_score(true,predicted)
    return mae,mse,rmse,r2_score
